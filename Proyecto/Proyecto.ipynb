# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations

# Ajustes globales para gráficos
plt.rcParams["figure.figsize"] = (7.5, 5.0)
plt.rcParams["axes.grid"] = True

DATA_PATH = "population_data.csv"  

# Funciones de estadpística
class StatsUtils:

    @staticmethod
    def mean(x: np.ndarray) -> float: # Promedio
        return float(np.sum(x) / len(x))

    @staticmethod
    def var(x: np.ndarray) -> float: # Varianza
        mu = StatsUtils.mean(x)
        return float(np.sum((x - mu) ** 2) / (len(x) - 1))

    @staticmethod
    def std(x: np.ndarray) -> float: # Desviación estándar
        return float(np.sqrt(StatsUtils.var(x)))

    @staticmethod
    def cov(x: np.ndarray, y: np.ndarray) -> float: # Covarianza
        mx, my = StatsUtils.mean(x), StatsUtils.mean(y)
        return float(np.sum((x - mx) * (y - my)) / (len(x) - 1))

    @staticmethod
    def corr(x: np.ndarray, y: np.ndarray) -> float: # Correlación de Pearson
        vx, vy = StatsUtils.var(x), StatsUtils.var(y)
        if vx == 0 or vy == 0:
            return np.nan
        return StatsUtils.cov(x, y) / (np.sqrt(vx) * np.sqrt(vy))

    @staticmethod
    def linear_regression(x: np.ndarray, y: np.ndarray) -> tuple[float, float, float]: # Regresión lineal (MCO)
        mx, my = StatsUtils.mean(x), StatsUtils.mean(y) 
        # Suma de cuadrados
        sxx = float(np.sum((x - mx) ** 2)) 
        sxy = float(np.sum((x - mx) * (y - my)))

        if sxx == 0: # Pendiente cero que da R^2 = 0
            return float(my), np.nan, 0.0

        a1 = sxy / sxx
        a0 = my - a1 * mx

        y_hat = a0 + a1 * x
        ss_res = float(np.sum((y - y_hat) ** 2))
        ss_tot = float(np.sum((y - my) ** 2))
        r2 = 0.0 if ss_tot == 0 else 1.0 - ss_res / ss_tot
        return float(a0), float(a1), float(r2)

# Estimador de distribución de probabilidad con histograma
class PDFEstimator:

    def __init__(self, bins: int | None = None):
        self.bins = bins

    @staticmethod 
    def _auto_bins(n: int) -> int: # Generación de número de bins
        return int(np.ceil(np.sqrt(n))) if n > 0 else 1

    def estimate(self, x: np.ndarray) -> tuple[np.ndarray, np.ndarray]: # Estimación de función de densidad de probabilidad
        data = x[~np.isnan(x)]
        n_bins = self.bins or self._auto_bins(len(data))
        counts, edges = np.histogram(data, bins=n_bins, density=True)
        centers = 0.5 * (edges[:-1] + edges[1:])
        return centers, counts

    def plot(self, series: pd.Series, title: str| None = None) -> None:
        values = series.values.astype(float)
        centers, pdf = self.estimate(values)
        width = (centers[1] - centers[0]) if len(centers) > 1 else 1.0
        plt.figure()
        plt.bar(centers, pdf, width=width)
        plt.xlabel(series.name)
        plt.ylabel("Densidad aprox.")
        plt.title(title or f"Distribución aproximada de {series.name}")
        plt.show()

# Analizar el dataset
class DatasetAnalyzer:

    def __init__(self, df: pd.DataFrame, class_column: str| None = None): # Constructor
        self.df = df.copy()
        self.class_column = class_column
        self.numeric_columns = [
            c for c in self.df.columns if np.issubdtype(self.df[c].dtype, np.number) # Filtrar columnas numéricas
        ]

    def correlation_matrix(self) -> pd.DataFrame:
        cols = self.numeric_columns
        corr_mat = np.full((len(cols), len(cols)), np.nan, dtype=float)
        for i, ci in enumerate(cols):
            xi = self.df[ci].values.astype(float)
            for j, cj in enumerate(cols):
                xj = self.df[cj].values.astype(float)
                corr_mat[i, j] = StatsUtils.corr(xi, xj)
        return pd.DataFrame(corr_mat, index=cols, columns=cols)

    def linear_regression_pairs(self) -> pd.DataFrame:
        rows = []
        for x_name, y_name in combinations(self.numeric_columns, 2):
            x = self.df[x_name].values.astype(float)
            y = self.df[y_name].values.astype(float)
            a0, a1, r2 = StatsUtils.linear_regression(x, y)
            rows.append({"x": x_name, "y": y_name, "a0": a0, "a1": a1, "R2": r2})
            # Regresión inversa
            a0b, a1b, r2b = StatsUtils.linear_regression(y, x)
            rows.append({"x": y_name, "y": x_name, "a0": a0b, "a1": a1b, "R2": r2b})

        out = pd.DataFrame(rows)
        out["R2"] = out["R2"].clip(lower=0.0, upper=1.0)
        return out

    def sum_R2(self) -> float: # Sumatoria de errores para cada una de las parejas
        reg = self.linear_regression_pairs()
        return float(reg["R2"].sum())

    def _pick_or_build_classes(self, x_name: str, y_name: str) -> pd.Series:
        if False and (
            self.class_column is not None
            and self.class_column in self.df.columns
            and self.df[self.class_column].nunique() <= 10
        ):
            return self.df[self.class_column].astype(str)

        y = self.df[y_name].values.astype(float)
        y_clean = pd.Series(y).dropna()
        q1, q2 = y_clean.quantile([0.33, 0.66])
        def label_y(val: float) -> str:
            if np.isnan(val):
                return "sin datos"
            if val <= q1:
                return "bajo"
            if val <= q2:
                return "medio"
            return "alto"

        return pd.Series([label_y(v) for v in y], index=self.df.index, name="class")

    def scatter_with_regression( # Gráfica de dispersión con recta de regresión
        self, x_name: str, y_name: str, show_regression: bool = True
    ) -> None:
        x = self.df[x_name].values.astype(float)
        y = self.df[y_name].values.astype(float)

        # Clases para colorear dependiendo si es alto, medio o bajo o ya está la categoría
        class_labels = self._pick_or_build_classes(x_name, y_name)

        # Graficar por grupo de clase
        plt.figure()
        for label, group_idx in class_labels.groupby(class_labels).groups.items():
            plt.scatter(x[group_idx], y[group_idx], label=str(label))
        plt.xlabel(x_name)
        plt.ylabel(y_name)
        plt.title(f"Dispersión: {x_name} vs {y_name}")
        plt.legend()

        # Regresión lineal
        if show_regression:
            a0, a1, r2 = StatsUtils.linear_regression(x, y)
            x_line = np.linspace(np.nanmin(x), np.nanmax(x), 100)
            y_line = a0 + a1 * x_line
            plt.plot(x_line, y_line, linewidth=2)
            plt.title(
                f"{x_name} vs {y_name} (Regresión) — y = {a0:.3f} + {a1:.3f}x | R² = {r2:.3f}"
            )

        plt.show()

    def plot_all_pdfs(self) -> None: # Gráficas de distribución de probabilidad
        estimator = PDFEstimator()
        for col in self.numeric_columns:
            estimator.plot(self.df[col], title=f"Distribución aproximada de {col}")

    def plot_all_scatters(self, with_regression: bool = True) -> None: # Gráficas de dispersión con regresión
        for x_name, y_name in combinations(self.numeric_columns, 2):
            self.scatter_with_regression(x_name, y_name, show_regression=with_regression)

df = pd.read_csv(DATA_PATH)

# Quitar los ID's porque no son relevantes en el análisis
if "id" in df.columns:
    df = df.drop(columns=["id"])

# Detectar una posible columna categórica (pocas categorías)
possible_class_col = None
for col in df.columns:
    is_numeric = np.issubdtype(df[col].dtype, np.number)
    nunique = df[col].nunique(dropna=True)
    if (not is_numeric and nunique <= 10) or (is_numeric and nunique <= 10 and nunique > 1):
        possible_class_col = col
        break

analyzer = DatasetAnalyzer(df, class_column=possible_class_col)

corr_df = analyzer.correlation_matrix()
print("\n MATRIZ DE CORRELACIÓN DE PEARSON ")
display(corr_df.round(4))

# Distribuciones de probabilidad
analyzer.plot_all_pdfs()

# Gráficas de dispersión con la regresión lineal
analyzer.plot_all_scatters(with_regression=True)

#Coeficientes y error en regresión lineal
reg_table = analyzer.linear_regression_pairs().round(6)
print("COEFICIENTES Y R^2 (TODOS LOS PARES, AMBAS DIRECCIONES)")
display(reg_table)

total_r2 = analyzer.sum_R2()
print(f"\nSumatoria total de R^2 en todas las direcciones: {total_r2:.6f}")
# Out:
#  MATRIZ DE CORRELACIÓN DE PEARSON
#                  Population 2025  Yearly Change  Density (P/Km²)  \
# Population 2025           1.0000         0.0174          -0.0254
# Yearly Change             0.0174         1.0000          -0.0124
# Density (P/Km²)          -0.0254        -0.0124           1.0000
# Land Area (Km²)           0.4485         0.0219          -0.0582
# Fert. Rate               -0.0322         0.2079          -0.1256
# Median Age               -0.0139        -0.2523           0.1816
# Urban Pop                 0.0238        -0.0159          -0.0799
# World Share               0.9939         0.0123          -0.0215
#
#                  Land Area (Km²)  Fert. Rate  Median Age  Urban Pop  \
# Population 2025           0.4485     -0.0322     -0.0139     0.0238
# Yearly Change             0.0219      0.2079     -0.2523    -0.0159
# Density (P/Km²)          -0.0582     -0.1256      0.1816    -0.0799
# Land Area (Km²)           1.0000     -0.0194      0.0177     0.1608
# Fert. Rate               -0.0194      1.0000     -0.8548    -0.2279
# Median Age                0.0177     -0.8548      1.0000     0.1410
# Urban Pop                 0.1608     -0.2279      0.1410     1.0000
# World Share               0.4446     -0.0473      0.0025     0.0254
#
#                  World Share
# Population 2025       0.9939
# Yearly Change         0.0123
# Density (P/Km²)      -0.0215
# Land Area (Km²)       0.4446
# Fert. Rate           -0.0473
# Median Age            0.0025
# Urban Pop             0.0254
# World Share           1.0000
# COEFICIENTES Y R^2 (TODOS LOS PARES, AMBAS DIRECCIONES)
#                   x                y            a0            a1        R2
# 0   Population 2025    Yearly Change  5.142000e-03  0.000000e+00  0.000304
# 1     Yearly Change  Population 2025  3.506670e+07  4.732511e+07  0.000304
# 2   Population 2025  Density (P/Km²)  5.032275e+02 -0.000000e+00  0.000645
# 3   Density (P/Km²)  Population 2025  3.603539e+07 -1.465309e+03  0.000645
# 4   Population 2025  Land Area (Km²)  3.655353e+05  5.459000e-03  0.201113
# 5   Land Area (Km²)  Population 2025  1.475013e+07  3.684237e+01  0.201113
# 6   Population 2025       Fert. Rate  2.315358e+00 -0.000000e+00  0.001036
# 7        Fert. Rate  Population 2025  4.442762e+07 -3.949027e+06  0.001036
# 8   Population 2025       Median Age  3.193170e+01 -0.000000e+00  0.000192
# 9        Median Age  Population 2025  4.156467e+07 -1.957512e+05  0.000192
# 10  Population 2025        Urban Pop  5.465050e-01  0.000000e+00  0.000564
# 11        Urban Pop  Population 2025  2.886544e+07  1.177560e+07  0.000564
# 12  Population 2025      World Share -6.220000e-04  0.000000e+00  0.987907
# 13      World Share  Population 2025  5.456186e+06  8.091226e+09  0.987907
# 14    Yearly Change  Density (P/Km²)  4.908051e+02 -5.831982e+02  0.000154
# 15  Density (P/Km²)    Yearly Change  5.498000e-03 -0.000000e+00  0.000154
# 16    Yearly Change  Land Area (Km²)  5.544512e+05  7.247850e+05  0.000482
# 17  Land Area (Km²)    Yearly Change  4.998000e-03  0.000000e+00  0.000482
# 18    Yearly Change       Fert. Rate  2.281418e+00  4.596019e+00  0.043211
# 19       Fert. Rate    Yearly Change -1.631200e-02  9.402000e-03  0.043211
# 20    Yearly Change       Median Age  3.215739e+01 -4.849883e+01  0.063668
# 21       Median Age    Yearly Change  4.724300e-02 -1.313000e-03  0.063668
# 22    Yearly Change        Urban Pop  5.486640e-01 -8.688500e-02  0.000252
# 23        Urban Pop    Yearly Change  6.959000e-03 -2.900000e-03  0.000252
# 24    Yearly Change      World Share  3.669000e-03  4.115000e-03  0.000152
# 25      World Share    Yearly Change  5.232000e-03  3.704500e-02  0.000152
# 26  Density (P/Km²)  Land Area (Km²)  5.782762e+05 -4.087466e+01  0.003389
# 27  Land Area (Km²)  Density (P/Km²)  5.339633e+02 -8.300000e-05  0.003389
# 28  Density (P/Km²)       Fert. Rate  2.334881e+00 -5.900000e-05  0.015767
# 29       Fert. Rate  Density (P/Km²)  1.103640e+03 -2.671038e+02  0.015767
# 30  Density (P/Km²)       Median Age  3.153509e+01  7.420000e-04  0.032976
# 31       Median Age  Density (P/Km²) -9.296677e+02  4.443496e+01  0.032976
# 32  Density (P/Km²)        Urban Pop  5.527300e-01 -9.000000e-06  0.006379
# 33        Urban Pop  Density (P/Km²)  8.638895e+02 -6.862777e+02  0.006379
# 34  Density (P/Km²)      World Share  3.765000e-03 -0.000000e+00  0.000464
# 35      World Share  Density (P/Km²)  4.988944e+02 -3.039988e+03  0.000464
# 36  Land Area (Km²)       Fert. Rate  2.313359e+00 -0.000000e+00  0.000378
# 37       Fert. Rate  Land Area (Km²)  6.252785e+05 -2.902562e+04  0.000378
# 38  Land Area (Km²)       Median Age  3.183948e+01  0.000000e+00  0.000313
# 39       Median Age  Land Area (Km²)  4.613518e+05  3.040752e+03  0.000313
# 40  Land Area (Km²)        Urban Pop  5.333150e-01  0.000000e+00  0.025865
# 41        Urban Pop  Land Area (Km²)  2.639703e+04  9.703541e+05  0.025865
# 42  Land Area (Km²)      World Share  1.186000e-03  0.000000e+00  0.197673
# 43      World Share  Land Area (Km²)  3.957333e+05  4.405579e+07  0.197673
# 44       Fert. Rate       Median Age  4.903299e+01 -7.430744e+00  0.730628
# 45       Median Age       Fert. Rate  5.442369e+00 -9.832500e-02  0.730628
# 46       Fert. Rate        Urban Pop  6.783310e-01 -5.643000e-02  0.051960
# 47        Urban Pop       Fert. Rate  2.810871e+00 -9.207930e-01  0.051960
# 48       Fert. Rate      World Share  5.334000e-03 -7.130000e-04  0.002235
# 49      World Share       Fert. Rate  2.317672e+00 -3.136585e+00  0.002235
# 50       Median Age        Urban Pop  4.201570e-01  4.014000e-03  0.019871
# 51        Urban Pop       Median Age  2.918335e+01  4.950121e+00  0.019871
# 52       Median Age      World Share  3.550000e-03  4.000000e-06  0.000006
# 53      World Share       Median Age  3.189158e+01  1.468228e+00  0.000006
# 54        Urban Pop      World Share  2.844000e-03  1.544000e-03  0.000643
# 55      World Share        Urban Pop  5.466600e-01  4.165120e-01  0.000643
# Sumatoria total de R^2 en todas las direcciones: 4.776454
