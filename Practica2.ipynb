# %%
import matplotlib.pyplot as plt
import numpy as np

def graficar_circulo(a: float, b: float, r: float):
    plt.figure(figsize=(4,4))
    x = np.linspace(-10,10,100)
    y = (((r**2)-(x-a)**2)**(1/2))+b
    y = -(((r**2)-(x-a)**2)**(1/2))+b
    plt.plot(x,y)

graficar_circulo(0,0,2)
# Out:
# C:\Users\salaz\AppData\Local\Temp\ipykernel_15000\3816971369.py:7: RuntimeWarning: invalid value encountered in sqrt
#   y = (((r**2)-(x-a)**2)**(1/2))+b
# C:\Users\salaz\AppData\Local\Temp\ipykernel_15000\3816971369.py:8: RuntimeWarning: invalid value encountered in sqrt
#   y = -(((r**2)-(x-a)**2)**(1/2))+b
